# %%
from feature_engineer import get_engineered_df_allWC
from feature_no_distance import get_features_without_distance_allWC
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
warehouse_name = "OE"
DATA_PATH = "~/Lucas_Systems_Capstone_Project/data/processed/oe_detailed.parquet"
work_code = "30"
df, feature_cols, cat_cols = get_features_without_distance_allWC(DATA_PATH, warehouse=warehouse_name, max_time=300)

# %%
df.head(5)
# Out:
#   ActivityCode UserID WorkCode AssignmentID  ProductID  Quantity  \
# 1      PickPut    143       30      7717860        460        50
# 2      PickPut    143       30      7717908        460       100
# 3      PickPut    143       30      7717921      44547        13
# 4      PickPut    143       30      7717920      44547        13
# 5      PickPut    143       30      7717815        191         8
#
#                 Timestamp  LocationID  Time_Delta_sec ProductCode  ... Aisle2  \
# 1 2025-09-08 12:12:18.127         422          27.297  6487PBBSJC  ...     40
# 2 2025-09-08 12:15:46.650         422         208.523  6487PBBSJC  ...     40
# 3 2025-09-08 12:16:30.470       10743          43.820  635806236Y  ...     40
# 4 2025-09-08 12:18:00.970       10743          90.500  635806236Y  ...     40
# 5 2025-09-08 12:18:45.173        2985          44.203  0723306546  ...     40
#
#    Bay2    LocKey  Aisle_group  Level_group  hour  time_of_day UOM_group  \
# ...

# %%
df.columns
# Out:
# Index(['ActivityCode', 'UserID', 'WorkCode', 'AssignmentID', 'ProductID',
#        'Quantity', 'Timestamp', 'LocationID', 'Time_Delta_sec', 'ProductCode',
#        'UnitOfMeasure', 'Weight', 'Cube', 'Aisle', 'Bay', 'Level', 'Slot',
#        'Aisle2', 'Bay2', 'LocKey', 'Aisle_group', 'Level_group', 'hour',
#        'time_of_day', 'UOM_group', 'day_of_week', 'top_100_product'],
#       dtype='object')

# %%
feature_cols
# Out:
# ['WorkCode',
#  'Weight',
#  'Cube',
#  'Quantity',
#  'Aisle_group',
#  'Level_group',
#  'time_of_day',
#  'UOM_group',
#  'day_of_week',
#  'top_100_product']

# %%
cat_cols
# Out:
# ['WorkCode',
#  'Aisle_group',
#  'Level_group',
#  'time_of_day',
#  'UOM_group',
#  'day_of_week',
#  'top_100_product']
