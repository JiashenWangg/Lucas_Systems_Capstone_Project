# %%
import pandas as pd
import numpy as np
import time
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error
from feature_engineer import get_engineered_df
warehouses = ["OE", "OF"]
work_codes = ["10", "20", "30"]
max_time = 300
min_train_days = 3
all_results = []

# %%
# DATA_PATH = f"~/Lucas_Systems_Capstone_Project/data/processed/oe_detailed.parquet"
# df, features, cat_cols = get_engineered_df(DATA_PATH, warehouse='OE', work_code='30', max_time=max_time)

# %%
for wh in warehouses:
    DATA_PATH = f"~/Lucas_Systems_Capstone_Project/data/processed/{wh.lower()}_detailed.parquet"
    
    for wc in work_codes:
        print(f"\n--- Processing {wh} | WorkCode {wc} ---")
        
        # 1. Load and Engineer Features
        # Assuming get_engineered_df returns a 'Date' or 'Start_Time' column
        df, features, cat_cols = get_engineered_df(DATA_PATH, warehouse=wh, work_code=wc, max_time=max_time)
        
        df['Date'] = pd.to_datetime(df['Timestamp']).dt.date
        df = df.sort_values('Timestamp') # Sort chronologically
        
        unique_dates = sorted(df['Date'].unique())        

        # 2. Iterative Time Splits (Expanding Window)
        for i in range(min_train_days, len(unique_dates)):
            train_dates = unique_dates[:i]
            test_date = unique_dates[i]
            
            print(f"  Split {i-min_train_days+1}: Training through {train_dates[-1]} | Testing on {test_date}")
            
            train_df = df[df['Date'].isin(train_dates)]
            test_df = df[df['Date'] == test_date]
            
            # Scenarios: With Distance vs Without Distance (getting rid of efficient_user)
            scenarios = {
                "With Distance": {
                    "features": [f for f in features if f != "efficient_user"],
                    "cat_cols": [c for c in cat_cols if c != "efficient_user"]
                },
                "Without Distance": {
                    "features": [f for f in features if f not in ["Travel_Distance", "same_aisle", "same_lockey", "diff_level", "efficient_user"]],
                    "cat_cols": [c for c in cat_cols if c not in ["same_aisle", "same_lockey", "diff_level", "efficient_user"]]
                }
            }
            
            for name, config in scenarios.items():
                # Prepare X and y
                # We use get_dummies on the subset to avoid data leakage 
                # (though in this context, we align columns to match)
                X_train = pd.get_dummies(train_df[config['features']], columns=config['cat_cols'], drop_first=True)
                y_train = train_df["Time_Delta_sec"]
                
                X_test = pd.get_dummies(test_df[config['features']], columns=config['cat_cols'], drop_first=True)
                y_test = test_df["Time_Delta_sec"]
                
                # Align columns between train and test (handling missing dummy categories)
                X_test = X_test.reindex(columns=X_train.columns, fill_value=0)
                
                # 3. Model Training (reduced max_depth from 6 to 3, changed objective from default to absolute error, added a min child weight)
                model = XGBRegressor(
                    objective='reg:absoluteerror', 
                    n_estimators=1000, 
                    learning_rate=0.05, 
                    max_depth=3, 
                    min_child_weight=5, 
                    random_state=42, 
                    n_jobs=-1
                )

                model.fit(X_train, y_train)      

                # 4. Evaluation
                preds = model.predict(X_test)
                r2 = r2_score(y_test, preds)
                mae = mean_absolute_error(y_test, preds)
                
                # 5. Store Results
                all_results.append({
                    "Warehouse": wh,
                    "WorkCode": wc,
                    "Scenario": name,
                    "Train_End_Date": train_dates[-1],
                    "Test_Date": test_date,
                    "Train_Days_Count": len(train_dates),
                    "Train_Rows": len(X_train),
                    "Test_Rows": len(X_test),
                    "R^2": round(r2, 4),
                    "MAE": round(mae, 2)
                })

# 6. Display Results
results_df = pd.DataFrame(all_results)
display(results_df)
# Out:
# --- Processing OE | WorkCode 10 ---
#   Split 1: Training through 2025-11-10 | Testing on 2025-11-11
#   Split 2: Training through 2025-11-11 | Testing on 2025-11-12
#   Split 3: Training through 2025-11-12 | Testing on 2025-11-13
#   Split 4: Training through 2025-11-13 | Testing on 2025-12-01
#   Split 5: Training through 2025-12-01 | Testing on 2025-12-02
#
# --- Processing OE | WorkCode 20 ---
#   Split 1: Training through 2025-11-10 | Testing on 2025-11-11
#   Split 2: Training through 2025-11-11 | Testing on 2025-11-12
#   Split 3: Training through 2025-11-12 | Testing on 2025-11-13
#   Split 4: Training through 2025-11-13 | Testing on 2025-12-01
#   Split 5: Training through 2025-12-01 | Testing on 2025-12-02
#
# --- Processing OE | WorkCode 30 ---
#   Split 1: Training through 2025-11-10 | Testing on 2025-11-11
#   Split 2: Training through 2025-11-11 | Testing on 2025-11-12
#   Split 3: Training through 2025-11-12 | Testing on 2025-11-13
#   Split 4: Training through 2025-11-13 | Testing on 2025-12-01
#   Split 5: Training through 2025-12-01 | Testing on 2025-12-02
#
# --- Processing OF | WorkCode 10 ---
#   Split 1: Training through 2025-09-08 | Testing on 2025-09-09
#   Split 2: Training through 2025-09-09 | Testing on 2025-11-10
#   Split 3: Training through 2025-11-10 | Testing on 2025-11-11
#   Split 4: Training through 2025-11-11 | Testing on 2025-11-12
#   Split 5: Training through 2025-11-12 | Testing on 2025-11-13
#   Split 6: Training through 2025-11-13 | Testing on 2025-12-01
#   Split 7: Training through 2025-12-01 | Testing on 2025-12-02
#
# --- Processing OF | WorkCode 20 ---
#   Split 1: Training through 2025-09-09 | Testing on 2025-11-10
#   Split 2: Training through 2025-11-10 | Testing on 2025-11-11
#   Split 3: Training through 2025-11-11 | Testing on 2025-11-12
#   Split 4: Training through 2025-11-12 | Testing on 2025-11-13
#   Split 5: Training through 2025-11-13 | Testing on 2025-11-30
#   Split 6: Training through 2025-11-30 | Testing on 2025-12-01
#   Split 7: Training through 2025-12-01 | Testing on 2025-12-02
#   Split 8: Training through 2025-12-02 | Testing on 2025-12-03
#
# --- Processing OF | WorkCode 30 ---
#   Split 1: Training through 2025-09-09 | Testing on 2025-11-10
#   Split 2: Training through 2025-11-10 | Testing on 2025-11-11
#   Split 3: Training through 2025-11-11 | Testing on 2025-11-12
#   Split 4: Training through 2025-11-12 | Testing on 2025-11-13
#   Split 5: Training through 2025-11-13 | Testing on 2025-11-30
#   Split 6: Training through 2025-11-30 | Testing on 2025-12-01
#   Split 7: Training through 2025-12-01 | Testing on 2025-12-02
#   Split 8: Training through 2025-12-02 | Testing on 2025-12-03
#    Warehouse WorkCode          Scenario Train_End_Date   Test_Date  \
# 0         OE       10     With Distance     2025-11-10  2025-11-11
# 1         OE       10  Without Distance     2025-11-10  2025-11-11
# 2         OE       10     With Distance     2025-11-11  2025-11-12
# 3         OE       10  Without Distance     2025-11-11  2025-11-12
# 4         OE       10     With Distance     2025-11-12  2025-11-13
# 5         OE       10  Without Distance     2025-11-12  2025-11-13
# 6         OE       10     With Distance     2025-11-13  2025-12-01
# 7         OE       10  Without Distance     2025-11-13  2025-12-01
# 8         OE       10     With Distance     2025-12-01  2025-12-02
# 9         OE       10  Without Distance     2025-12-01  2025-12-02
# 10        OE       20     With Distance     2025-11-10  2025-11-11
# 11        OE       20  Without Distance     2025-11-10  2025-11-11
# 12        OE       20     With Distance     2025-11-11  2025-11-12
# 13        OE       20  Without Distance     2025-11-11  2025-11-12
# 14        OE       20     With Distance     2025-11-12  2025-11-13
# 15        OE       20  Without Distance     2025-11-12  2025-11-13
# 16        OE       20     With Distance     2025-11-13  2025-12-01
# 17        OE       20  Without Distance     2025-11-13  2025-12-01
# 18        OE       20     With Distance     2025-12-01  2025-12-02
# 19        OE       20  Without Distance     2025-12-01  2025-12-02
# 20        OE       30     With Distance     2025-11-10  2025-11-11
# 21        OE       30  Without Distance     2025-11-10  2025-11-11
# 22        OE       30     With Distance     2025-11-11  2025-11-12
# 23        OE       30  Without Distance     2025-11-11  2025-11-12
# 24        OE       30     With Distance     2025-11-12  2025-11-13
# 25        OE       30  Without Distance     2025-11-12  2025-11-13
# 26        OE       30     With Distance     2025-11-13  2025-12-01
# 27        OE       30  Without Distance     2025-11-13  2025-12-01
# 28        OE       30     With Distance     2025-12-01  2025-12-02
# 29        OE       30  Without Distance     2025-12-01  2025-12-02
# 30        OF       10     With Distance     2025-09-08  2025-09-09
# 31        OF       10  Without Distance     2025-09-08  2025-09-09
# 32        OF       10     With Distance     2025-09-09  2025-11-10
# 33        OF       10  Without Distance     2025-09-09  2025-11-10
# 34        OF       10     With Distance     2025-11-10  2025-11-11
# 35        OF       10  Without Distance     2025-11-10  2025-11-11
# 36        OF       10     With Distance     2025-11-11  2025-11-12
# 37        OF       10  Without Distance     2025-11-11  2025-11-12
# 38        OF       10     With Distance     2025-11-12  2025-11-13
# 39        OF       10  Without Distance     2025-11-12  2025-11-13
# 40        OF       10     With Distance     2025-11-13  2025-12-01
# 41        OF       10  Without Distance     2025-11-13  2025-12-01
# 42        OF       10     With Distance     2025-12-01  2025-12-02
# 43        OF       10  Without Distance     2025-12-01  2025-12-02
# 44        OF       20     With Distance     2025-09-09  2025-11-10
# 45        OF       20  Without Distance     2025-09-09  2025-11-10
# 46        OF       20     With Distance     2025-11-10  2025-11-11
# 47        OF       20  Without Distance     2025-11-10  2025-11-11
# 48        OF       20     With Distance     2025-11-11  2025-11-12
# 49        OF       20  Without Distance     2025-11-11  2025-11-12
# 50        OF       20     With Distance     2025-11-12  2025-11-13
# 51        OF       20  Without Distance     2025-11-12  2025-11-13
# 52        OF       20     With Distance     2025-11-13  2025-11-30
# 53        OF       20  Without Distance     2025-11-13  2025-11-30
# 54        OF       20     With Distance     2025-11-30  2025-12-01
# 55        OF       20  Without Distance     2025-11-30  2025-12-01
# 56        OF       20     With Distance     2025-12-01  2025-12-02
# 57        OF       20  Without Distance     2025-12-01  2025-12-02
# 58        OF       20     With Distance     2025-12-02  2025-12-03
# 59        OF       20  Without Distance     2025-12-02  2025-12-03
# 60        OF       30     With Distance     2025-09-09  2025-11-10
# 61        OF       30  Without Distance     2025-09-09  2025-11-10
# 62        OF       30     With Distance     2025-11-10  2025-11-11
# 63        OF       30  Without Distance     2025-11-10  2025-11-11
# 64        OF       30     With Distance     2025-11-11  2025-11-12
# 65        OF       30  Without Distance     2025-11-11  2025-11-12
# 66        OF       30     With Distance     2025-11-12  2025-11-13
# 67        OF       30  Without Distance     2025-11-12  2025-11-13
# 68        OF       30     With Distance     2025-11-13  2025-11-30
# 69        OF       30  Without Distance     2025-11-13  2025-11-30
# 70        OF       30     With Distance     2025-11-30  2025-12-01
# 71        OF       30  Without Distance     2025-11-30  2025-12-01
# 72        OF       30     With Distance     2025-12-01  2025-12-02
# 73        OF       30  Without Distance     2025-12-01  2025-12-02
# 74        OF       30     With Distance     2025-12-02  2025-12-03
# 75        OF       30  Without Distance     2025-12-02  2025-12-03
#
#     Train_Days_Count  Train_Rows  Test_Rows     R^2    MAE
# 0                  3        1625        563  0.3260  32.22
# 1                  3        1625        563  0.1211  38.87
# 2                  4        2188        483  0.2194  36.30
# 3                  4        2188        483 -0.1077  45.97
# 4                  5        2671        427  0.2972  31.12
# 5                  5        2671        427  0.0259  38.38
# 6                  6        3098        501  0.3051  34.33
# 7                  6        3098        501  0.0037  43.84
# 8                  7        3599        483  0.2720  39.84
# 9                  7        3599        483  0.0686  46.96
# 10                 3        8613       2026  0.6210  16.35
# 11                 3        8613       2026 -0.1031  34.36
# 12                 4       10639       2274  0.6085  15.54
# 13                 4       10639       2274 -0.0920  32.57
# 14                 5       12913       2433  0.6247  16.07
# 15                 5       12913       2433 -0.1056  34.13
# 16                 6       15346       2964  0.6046  15.13
# 17                 6       15346       2964 -0.0672  33.40
# 18                 7       18310       3024  0.6604  15.10
# 19                 7       18310       3024 -0.1080  33.08
# 20                 3       25466       6779  0.3719  21.09
# 21                 3       25466       6779  0.0353  26.49
# 22                 4       32245       7159  0.3444  21.26
# 23                 4       32245       7159  0.0496  25.88
# 24                 5       39404       8265  0.3716  19.99
# 25                 5       39404       8265  0.0796  24.99
# 26                 6       47669      10765  0.3125  21.20
# 27                 6       47669      10765  0.0648  25.15
# 28                 7       58434       6864  0.3734  20.56
# 29                 7       58434       6864  0.0669  25.28
# 30                 3         867        458  0.4919  24.91
# 31                 3         867        458 -0.1496  48.88
# 32                 4        1325        720  0.4967  27.16
# 33                 4        1325        720  0.0385  43.96
# 34                 5        2045        584  0.5686  21.23
# 35                 5        2045        584  0.0512  40.74
# 36                 6        2629        483  0.5279  24.85
# 37                 6        2629        483  0.0510  44.47
# 38                 7        3112        641  0.5376  23.01
# 39                 7        3112        641  0.0515  41.26
# 40                 8        3753        457  0.4478  30.39
# 41                 8        3753        457 -0.0508  47.44
# 42                 9        4210        466  0.5649  24.38
# 43                 9        4210        466 -0.0211  46.13
# 44                 3       10196       5029  0.6676  14.49
# 45                 3       10196       5029  0.0382  32.34
# 46                 4       15225       4312  0.6310  15.98
# 47                 4       15225       4312  0.0102  33.47
# 48                 5       19537       4359  0.6601  15.73
# 49                 5       19537       4359 -0.0359  35.40
# 50                 6       23896       4765  0.6480  14.76
# 51                 6       23896       4765  0.0031  31.46
# 52                 7       28661        809  0.5643  15.09
# 53                 7       28661        809 -0.0386  28.59
# 54                 8       29470       5728  0.6225  15.00
# 55                 8       29470       5728 -0.0269  29.92
# 56                 9       35198       4329  0.6230  14.54
# 57                 9       35198       4329 -0.0018  29.68
# 58                10       39527        611  0.6046  16.62
# 59                10       39527        611 -0.0447  39.30
# 60                 3       19204       9871  0.2747  27.80
# 61                 3       19204       9871 -0.0266  33.84
# 62                 4       29075       8328  0.3567  26.47
# 63                 4       29075       8328  0.0648  32.77
# 64                 5       37403       8609  0.3189  28.51
# 65                 5       37403       8609  0.0060  35.30
# 66                 6       46012       8382  0.3176  27.66
# 67                 6       46012       8382  0.0248  33.67
# 68                 7       54394       2724  0.3315  27.12
# 69                 7       54394       2724  0.0317  34.04
# 70                 8       57118       9943  0.2779  27.99
# 71                 8       57118       9943  0.0167  33.39
# 72                 9       67061       8093  0.3501  26.47
# 73                 9       67061       8093  0.0771  32.61
# 74                10       75154        304  0.4155  28.74
# 75                10       75154        304  0.0795  38.14

# %%
pd.set_option('display.max_rows', None)
display(results_df)
# Out:
#    Warehouse WorkCode          Scenario Train_End_Date   Test_Date  \
# 0         OE       10     With Distance     2025-11-10  2025-11-11
# 1         OE       10  Without Distance     2025-11-10  2025-11-11
# 2         OE       10     With Distance     2025-11-11  2025-11-12
# 3         OE       10  Without Distance     2025-11-11  2025-11-12
# 4         OE       10     With Distance     2025-11-12  2025-11-13
# 5         OE       10  Without Distance     2025-11-12  2025-11-13
# 6         OE       10     With Distance     2025-11-13  2025-12-01
# 7         OE       10  Without Distance     2025-11-13  2025-12-01
# 8         OE       10     With Distance     2025-12-01  2025-12-02
# 9         OE       10  Without Distance     2025-12-01  2025-12-02
# 10        OE       20     With Distance     2025-11-10  2025-11-11
# 11        OE       20  Without Distance     2025-11-10  2025-11-11
# 12        OE       20     With Distance     2025-11-11  2025-11-12
# 13        OE       20  Without Distance     2025-11-11  2025-11-12
# 14        OE       20     With Distance     2025-11-12  2025-11-13
# 15        OE       20  Without Distance     2025-11-12  2025-11-13
# 16        OE       20     With Distance     2025-11-13  2025-12-01
# 17        OE       20  Without Distance     2025-11-13  2025-12-01
# 18        OE       20     With Distance     2025-12-01  2025-12-02
# 19        OE       20  Without Distance     2025-12-01  2025-12-02
# 20        OE       30     With Distance     2025-11-10  2025-11-11
# 21        OE       30  Without Distance     2025-11-10  2025-11-11
# 22        OE       30     With Distance     2025-11-11  2025-11-12
# 23        OE       30  Without Distance     2025-11-11  2025-11-12
# 24        OE       30     With Distance     2025-11-12  2025-11-13
# 25        OE       30  Without Distance     2025-11-12  2025-11-13
# 72                 9       67061       8093  0.3501  26.47
# 73                 9       67061       8093  0.0771  32.61
# 74                10       75154        304  0.4155  28.74
# 75                10       75154        304  0.0795  38.14

# %%
# Save to CSV for persistent tracking
results_df.to_csv("time_split_results.csv", index=False)

# %%
import matplotlib.pyplot as plt

# Filter for the "Without Distance" scenario
plot_df = results_df[results_df['Scenario'] == 'With Distance'][results_df["Warehouse"] == 'OE'].copy()

# Sort by the test date to ensure a chronological line
plot_df = plot_df.sort_values('Test_Date')

fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot MAE (Lower is better)
color = 'tab:red'
ax1.set_xlabel('Test Date')
ax1.set_ylabel('MAE (Seconds)', color=color)
ax1.plot(plot_df['Test_Date'], plot_df['MAE'], marker='o', color=color, label='MAE')
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(True, linestyle='--', alpha=0.6)

# Create a second y-axis for R^2 (Higher is better)
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('R^2 Score', color=color)
ax2.plot(plot_df['Test_Date'], plot_df['R^2'], marker='s', color=color, label='R^2')
ax2.tick_params(axis='y', labelcolor=color)

plt.title('Model Performance Over Time (Without Distance Scenario)')
fig.tight_layout()
plt.show()
# Out:
# /var/folders/r9/zx84vhy57q9_n8tk5dnw8g980000gn/T/ipykernel_76123/3347147717.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   plot_df = results_df[results_df['Scenario'] == 'With Distance'][results_df["Warehouse"] == 'OE'].copy()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter for the specific warehouse
wh_df = results_df[results_df["Warehouse"] == 'OE'].sort_values('Train_Days_Count')

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10), sharex=True)

# --- Subplot 1: MAE (The "Experience" Curve) ---
sns.lineplot(data=wh_df, x='Train_Days_Count', y='MAE', hue='Scenario', 
             marker='o', ax=ax1, palette=['tab:green', 'tab:red'], errorbar=None)
ax1.set_title('Error Reduction: Impact of Distance & Training Volume', fontsize=14)
ax1.set_ylabel('Average Error (Seconds)', fontsize=12)
ax1.grid(True, alpha=0.3)

# --- Subplot 2: R^2 (The "Quality" Benchmark) ---
sns.lineplot(data=wh_df, x='Train_Days_Count', y='R^2', hue='Scenario', 
             marker='o', ax=ax2, palette=['tab:green', 'tab:red'], errorbar=None)
# Add a baseline at 0 to explain negative R^2
ax2.axhline(0, color='black', linestyle='--', alpha=0.6, label='Baseline (Mean Guess)')
ax2.set_title('Model Predictive Power (R² Score)', fontsize=14)
ax2.set_ylabel('R² Score', fontsize=12)
ax2.set_xlabel('Number of Days Used for Training', fontsize=12)
ax2.grid(True, alpha=0.3)

# Clean up legend
ax1.legend(title='Data Used')
ax2.legend(title='Data Used')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Executive Summary: Model Performance & Insights
#
# ### 1. Model Reliability (Generalization Over Time)
# By using an **Expanding Window Split** (training on days $1$ to $n$ and testing on day $n+1$), we have verified that the model generalizes effectively to new days of operation. As the training set grows, the model performance typically stabilizes, providing a reliable baseline for daily labor forecasting.
#
# ### 2. The Critical Role of Spatial Data
# Our analysis confirms that **Travel Distance** and spatial context (aisle/level groupings) are the primary drivers of accuracy:
# * **Accuracy Boost**: Including distance metrics reduces the average error (MAE) significantly.
# * **The "Distance Penalty"**: In high-performance segments like Work Code 20, removing distance data caused the prediction error to jump from **16.60s** to **40.29s**—a **142% increase in error**.
#
# ### 3. Key Performance Benchmarks
# * **High-Predictability Tasks (WC 20)**: The model explains over **63–65% of variance** ($R^2 > 0.60$) in travel time.
# * **Complex Tasks (WC 30)**: Even without user-level data, the model effectively captures core trends in pick-density and location-based variance.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Create a high-level summary table of the time-split results
summary_stats = results_df.groupby(['Warehouse', 'Scenario'])[['R^2', 'MAE']].mean().reset_index()

print("--- Average Performance per Scenario ---")
display(summary_stats)

# 2. Calculate the "Distance Impact" (ROI of Spatial Data)
# We compare 'With Distance' vs 'Without Distance' to show the % increase in error
pivot_mae = results_df.pivot_table(index=['Warehouse', 'Test_Date'], 
                                   columns='Scenario', 
                                   values='MAE')

pivot_mae['MAE_Increase_Percent'] = ((pivot_mae['Without Distance'] - pivot_mae['With Distance']) / 
                                     pivot_mae['With Distance'] * 100)

avg_penalty = pivot_mae['MAE_Increase_Percent'].mean()
print(f"\nAcross all test days, removing distance data increases average error by: {avg_penalty:.2f}%")

# 3. Visualization: Model Stability (Learning Curve)
# Filter for one warehouse to show a clean trend
for wh in results_df['Warehouse'].unique():
    wh_data = results_df[(results_df['Warehouse'] == wh) & (results_df['Scenario'] == 'With Distance')]
    
    plt.figure(figsize=(10, 4))
    plt.plot(wh_data['Test_Date'], wh_data['MAE'], marker='o', label=f'{wh} MAE (Lower is Better)', color='red')
    plt.title(f'Model Reliability Over Time: Warehouse {wh}')
    plt.xlabel('Operation Day (Test Set)')
    plt.ylabel('Seconds of Error (MAE)')
    plt.legend()
    plt.grid(True, linestyle='--')
    plt.show()
# Out:
# --- Average Performance per Scenario ---
#   Warehouse          Scenario       R^2        MAE
# 0        OE     With Distance  0.420847  23.740000
# 1        OE  Without Distance -0.004540  33.956667
# 2        OF     With Distance  0.491278  22.560870
# 3        OF  Without Distance  0.006448  36.817391
# Across all test days, removing distance data increases average error by: 57.39%

# %% [markdown]
# # **USING TSP OUTCOMES AS DISTANCE VARIABLE, running xgboost with this distance as a variable**

# %%
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error
from feature_engineer import get_engineered_df

# --- 1. TSP Heuristic (Nearest Neighbor) ---
def apply_tsp_optimization(df, dist_matrix):
    """
    Optimizes the task sequence per User/Date using a Greedy Nearest Neighbor 
    approach and returns a dataframe with recalculated travel distances.
    """
    optimized_rows = []
    # Grouping by UserID and Date to define the sequence "window"
    for (user, date), group in df.groupby(['UserID', 'Date']):
        if len(group) < 2:
            group['TSP_Distance'] = group['Travel_Distance']
            optimized_rows.append(group)
            continue
            
        locations = group['LocKey'].tolist()
        indices = group.index.tolist()
        unvisited = list(range(len(locations)))
        
        # Start at the first recorded pick of the day
        current_idx = unvisited.pop(0)
        route_indices = [indices[current_idx]]
        tsp_distances = [0.0] # First pick baseline
        
        while unvisited:
            curr_loc = locations[current_idx]
            # Find the closest unvisited location in the distance matrix
            next_idx = min(unvisited, key=lambda i: dist_matrix.loc[curr_loc, locations[i]])
            
            dist = dist_matrix.loc[curr_loc, locations[next_idx]]
            tsp_distances.append(dist)
            
            current_idx = next_idx
            route_indices.append(indices[current_idx])
            unvisited.remove(next_idx)
            
        # Reconstruct the group in optimized order while preserving original task data
        opt_group = df.loc[route_indices].copy()
        opt_group['TSP_Distance'] = tsp_distances
        
        # Update sequence-dependent flags based on the NEW sequence
        opt_group['Prev_Aisle'] = opt_group['Aisle'].shift(1)
        opt_group['same_aisle'] = (opt_group['Aisle'] == opt_group['Prev_Aisle']).astype(int)
        
        optimized_rows.append(opt_group)
        
    return pd.concat(optimized_rows)

# --- 2. Configurations ---
warehouses = ["OE"] # Starting with OE as per your tsp.ipynb
work_codes = ["30"]
max_time = 300
min_train_days = 3
all_results = []

# Load Distance Matrix
DIST_MATRIX_PATH = "../data/distance_matrices/distance_matrix_OE.csv"
dist_matrix = pd.read_csv(DIST_MATRIX_PATH, index_col=0)

for wh in warehouses:
    DATA_PATH = f"../data/processed/{wh.lower()}_detailed.parquet"
    
    for wc in work_codes:
        # Load and Engineer Features
        df, features, cat_cols = get_engineered_df(DATA_PATH, warehouse=wh, work_code=wc, max_time=max_time)
        df['Date'] = pd.to_datetime(df['Timestamp']).dt.date
        df = df.sort_values('Timestamp')
        
        unique_dates = sorted(df['Date'].unique())
        
        # Adjust features: Swap real distance for TSP distance, remove user-level data
        model_features = [f if f != 'Travel_Distance' else 'TSP_Distance' for f in features if f != 'efficient_user']
        model_cat_cols = [c for c in cat_cols if c != 'efficient_user']

        # --- 3. Expanding Window Loop ---
        for i in range(min_train_days, len(unique_dates)):
            train_dates = unique_dates[:i]
            test_date = unique_dates[i]
            
            # Apply TSP Optimization to Train and Test separately to avoid leakage
            train_df = apply_tsp_optimization(df[df['Date'].isin(train_dates)], dist_matrix)
            test_df = apply_tsp_optimization(df[df['Date'] == test_date], dist_matrix)
            
            # Prepare X and y
            X_train = pd.get_dummies(train_df[model_features], columns=model_cat_cols, drop_first=True)
            y_train = train_df["Time_Delta_sec"]
            
            X_test = pd.get_dummies(test_df[model_features], columns=model_cat_cols, drop_first=True)
            y_test = test_df["Time_Delta_sec"]
            
            X_test = X_test.reindex(columns=X_train.columns, fill_value=0)
            
            # Robust Model Training
            model = XGBRegressor(
                objective='reg:absoluteerror', 
                n_estimators=1000, 
                learning_rate=0.05, 
                max_depth=3, 
                min_child_weight=5, 
                random_state=42, 
                n_jobs=-1
            )
            model.fit(X_train, y_train)      

            # 4. Evaluation
            preds = model.predict(X_test)
            r2 = r2_score(y_test, preds)
            mae = mean_absolute_error(y_test, preds)
        
            all_results.append({
                    "Warehouse": wh,
                    "WorkCode": wc,
                    "Scenario": "TSP Optimized Distance",
                    "Train_End_Date": train_dates[-1],
                    "Test_Date": test_date,
                    "Train_Days_Count": len(train_dates),
                    "Train_Rows": len(X_train),
                    "Test_Rows": len(X_test),
                    "R^2": round(r2, 4),
                    "MAE": round(mae, 2)
                })
            
results_df = pd.DataFrame(all_results)
display(results_df)
# Out:
#   Warehouse WorkCode                Scenario Train_End_Date   Test_Date  \
# 0        OE       30  TSP Optimized Distance     2025-11-10  2025-11-11
# 1        OE       30  TSP Optimized Distance     2025-11-11  2025-11-12
# 2        OE       30  TSP Optimized Distance     2025-11-12  2025-11-13
# 3        OE       30  TSP Optimized Distance     2025-11-13  2025-12-01
# 4        OE       30  TSP Optimized Distance     2025-12-01  2025-12-02
#
#    Train_Days_Count  Train_Rows  Test_Rows     R^2    MAE
# 0                 3       25466       6779  0.1989  23.38
# 1                 4       32245       7159  0.1890  23.36
# 2                 5       39404       8265  0.2270  21.90
# 3                 6       47669      10765  0.1816  22.92
# 4                 7       58434       6864  0.2059  22.75

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter for the specific warehouse
wh_df = results_df[results_df["Warehouse"] == 'OE'].sort_values('Train_Days_Count')

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10), sharex=True)

# --- Subplot 1: MAE (The "Experience" Curve) ---
sns.lineplot(data=wh_df, x='Train_Days_Count', y='MAE', hue='Scenario', 
             marker='o', ax=ax1, palette=['tab:green', 'tab:red'], errorbar=None)
ax1.set_title('Error Reduction: Impact of Distance & Training Volume', fontsize=14)
ax1.set_ylabel('Average Error (Seconds)', fontsize=12)
ax1.grid(True, alpha=0.3)

# --- Subplot 2: R^2 (The "Quality" Benchmark) ---
sns.lineplot(data=wh_df, x='Train_Days_Count', y='R^2', hue='Scenario', 
             marker='o', ax=ax2, palette=['tab:green', 'tab:red'], errorbar=None)
# Add a baseline at 0
ax2.axhline(0, color='black', linestyle='--', alpha=0.6, label='Baseline (Mean Guess)')
ax2.set_title('Model Predictive Power (R² Score)', fontsize=14)
ax2.set_ylabel('R² Score', fontsize=12)
ax2.set_xlabel('Number of Days Used for Training', fontsize=12)
ax2.grid(True, alpha=0.3)

# Clean up legend
ax1.legend(title='Data Used')
ax2.legend(title='Data Used')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/r9/zx84vhy57q9_n8tk5dnw8g980000gn/T/ipykernel_76123/3231488241.py:10: UserWarning: The palette list has more values (2) than needed (1), which may not be intended.
#   sns.lineplot(data=wh_df, x='Train_Days_Count', y='MAE', hue='Scenario',
# /var/folders/r9/zx84vhy57q9_n8tk5dnw8g980000gn/T/ipykernel_76123/3231488241.py:17: UserWarning: The palette list has more values (2) than needed (1), which may not be intended.
#   sns.lineplot(data=wh_df, x='Train_Days_Count', y='R^2', hue='Scenario',

# %% [markdown]
# # **comparing regular distance model to tsp distance**

# %%
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error
from feature_engineer import get_engineered_df

# --- 1. TSP Heuristic (Nearest Neighbor) ---
def apply_tsp_optimization(df, dist_matrix):
    """
    Optimizes the task sequence per User/Date using a Greedy Nearest Neighbor 
    approach and returns a dataframe with recalculated travel distances.
    """
    optimized_rows = []
    # Grouping by UserID and Date to define the sequence "window"
    for (user, date), group in df.groupby(['UserID', 'Date']):
        if len(group) < 2:
            group['TSP_Distance'] = group['Travel_Distance']
            optimized_rows.append(group)
            continue
            
        locations = group['LocKey'].tolist()
        indices = group.index.tolist()
        unvisited = list(range(len(locations)))
        
        # Start at the first recorded pick of the day
        current_idx = unvisited.pop(0)
        route_indices = [indices[current_idx]]
        tsp_distances = [0.0] # First pick baseline
        
        while unvisited:
            curr_loc = locations[current_idx]
            # Find the closest unvisited location in the distance matrix
            next_idx = min(unvisited, key=lambda i: dist_matrix.loc[curr_loc, locations[i]])
            
            dist = dist_matrix.loc[curr_loc, locations[next_idx]]
            tsp_distances.append(dist)
            
            current_idx = next_idx
            route_indices.append(indices[current_idx])
            unvisited.remove(next_idx)
            
        # Reconstruct the group in optimized order while preserving original task data
        opt_group = df.loc[route_indices].copy()
        opt_group['TSP_Distance'] = tsp_distances
        
        # Update sequence-dependent flags based on the NEW sequence
        opt_group['Prev_Aisle'] = opt_group['Aisle'].shift(1)
        opt_group['same_aisle'] = (opt_group['Aisle'] == opt_group['Prev_Aisle']).astype(int)
        
        optimized_rows.append(opt_group)
        
    return pd.concat(optimized_rows)

# --- 2. Configurations ---
warehouses = ["OE"] # Starting with OE as per your tsp.ipynb
work_codes = ["30"]
max_time = 300
min_train_days = 3
all_results = []

# Load Distance Matrix
DIST_MATRIX_PATH = "../data/distance_matrices/distance_matrix_OE.csv"
dist_matrix = pd.read_csv(DIST_MATRIX_PATH, index_col=0)

for wh in warehouses:
    DATA_PATH = f"../data/processed/{wh.lower()}_detailed.parquet"
    
    for wc in work_codes:
        # Load and Engineer Features
        df, features, cat_cols = get_engineered_df(DATA_PATH, warehouse=wh, work_code=wc, max_time=max_time)
        df['Date'] = pd.to_datetime(df['Timestamp']).dt.date
        df = df.sort_values('Timestamp')
        
        unique_dates = sorted(df['Date'].unique())
        
        # Adjust features: Swap real distance for TSP distance, remove user-level data
        model_features = [f if f != 'Travel_Distance' else 'TSP_Distance' for f in features if f != 'efficient_user']
        model_cat_cols = [c for c in cat_cols if c != 'efficient_user']

        # --- 3. Expanding Window Loop ---
        for i in range(min_train_days, len(unique_dates)):
            train_dates = unique_dates[:i]
            test_date = unique_dates[i]
            
            # Apply TSP Optimization to Train and Test separately to avoid leakage
            train_df = apply_tsp_optimization(df[df['Date'].isin(train_dates)], dist_matrix)
            test_df = apply_tsp_optimization(df[df['Date'] == test_date], dist_matrix)
            
            # Prepare X and y
            X_train = pd.get_dummies(train_df[model_features], columns=model_cat_cols, drop_first=True)
            y_train = train_df["Time_Delta_sec"]
            
            X_test = pd.get_dummies(test_df[model_features], columns=model_cat_cols, drop_first=True)
            y_test = test_df["Time_Delta_sec"]
            
            X_test = X_test.reindex(columns=X_train.columns, fill_value=0)
            
            # Robust Model Training
            model = XGBRegressor(
                objective='reg:absoluteerror', 
                n_estimators=1000, 
                learning_rate=0.05, 
                max_depth=3, 
                min_child_weight=5, 
                random_state=42, 
                n_jobs=-1
            )
            model.fit(X_train, y_train)      

            # 4. Evaluation
            preds = model.predict(X_test)
            r2 = r2_score(y_test, preds)
            mae = mean_absolute_error(y_test, preds)
        
            all_results.append({
                    "Warehouse": wh,
                    "WorkCode": wc,
                    "Scenario": "TSP Optimized Distance",
                    "Train_End_Date": train_dates[-1],
                    "Test_Date": test_date,
                    "Train_Days_Count": len(train_dates),
                    "Train_Rows": len(X_train),
                    "Test_Rows": len(X_test),
                    "R^2": round(r2, 4),
                    "MAE": round(mae, 2)
                })
            
results_df = pd.DataFrame(all_results)
display(results_df)

# %%
def apply_tsp_optimization(df, dist_matrix):
    optimized_rows = []
    
    # Group by User and Date to find the logical "trip"
    for (user, date), group in df.groupby(['UserID', 'Date']):
        if len(group) < 2:
            group['TSP_Distance'] = group['Travel_Distance']
            optimized_rows.append(group)
            continue
            
        # 1. RUN THE TSP HEURISTIC (Nearest Neighbor)
        locations = group['LocKey'].tolist()
        indices = group.index.tolist()
        unvisited = list(range(len(locations)))
        
        current_idx = unvisited.pop(0) # Start at original first pick
        route_indices = [indices[current_idx]]
        tsp_distances = [0.0] 
        
        while unvisited:
            curr_loc = locations[current_idx]
            next_idx = min(unvisited, key=lambda i: dist_matrix.loc[curr_loc, locations[i]])
            
            tsp_distances.append(dist_matrix.loc[curr_loc, locations[next_idx]])
            current_idx = next_idx
            route_indices.append(indices[current_idx])
            unvisited.remove(next_idx)
            
        # 2. RECONSTRUCT THE GROUP IN TSP ORDER
        opt_group = df.loc[route_indices].copy()
        opt_group['TSP_Distance'] = tsp_distances
        
        # 3. RE-ENGINEER SEQUENCE-DEPENDENT FEATURES
        # These must be recalculated because the 'Previous' task has changed
        
        # Same Aisle?
        opt_group['Prev_Aisle'] = opt_group['Aisle'].shift(1)
        opt_group['same_aisle'] = (opt_group['Aisle'] == opt_group['Prev_Aisle']).astype(int)
        
        # Same Location?
        opt_group['Prev_LocKey'] = opt_group['LocKey'].shift(1)
        opt_group['same_lockey'] = (opt_group['LocKey'] == opt_group['Prev_LocKey']).astype(int)
        
        # Difference in Level (Vertical distance)?
        if 'Level' in opt_group.columns:
            opt_group['Prev_Level'] = opt_group['Level'].shift(1)
            opt_group['diff_level'] = ((opt_group['LocKey'] == opt_group['Prev_LocKey']) & 
                                   (opt_group['Level'] != opt_group['Prev_Level'])).astype(int)            
        # Drop the temporary 'Prev' columns to keep the dataframe clean
        opt_group = opt_group.drop(columns=['Prev_Aisle', 'Prev_LocKey', 'Prev_Level'], errors='ignore')
        
        optimized_rows.append(opt_group)
        
    return pd.concat(optimized_rows)

# %%
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error
from feature_engineer import get_engineered_df
all_results = []
warehouses = ["OE", "OF"]
work_codes = ["10", "20", "30"]
max_time = 300
min_train_days = 3


for wh in warehouses:
    # Load the distance matrix
    DIST_MATRIX_PATH = f"../data/distance_matrices/distance_matrix_{wh}.csv"
    dist_matrix = pd.read_csv(DIST_MATRIX_PATH, index_col=0)
    
    # Path to the specific warehouse data
    DATA_PATH = f"../data/processed/{wh.lower()}_detailed.parquet"
    
    for wc in work_codes:
        print(f"Starting Audit: Warehouse {wh} | Work Code {wc}")
        
        # Load and Engineer Features
        df, features, cat_cols = get_engineered_df(DATA_PATH, warehouse=wh, work_code=wc, max_time=max_time)
        df['Date'] = pd.to_datetime(df['Timestamp']).dt.date
        df = df.sort_values('Timestamp')
        unique_dates = sorted(df['Date'].unique())

        for i in range(min_train_days, len(unique_dates)):
            train_dates = unique_dates[:i]
            test_date = unique_dates[i]
            print(f"  > Auditing {wh}-{wc} | Test Date: {test_date}...")
            
            raw_train = df[df['Date'].isin(train_dates)].copy()
            raw_test = df[df['Date'] == test_date].copy()
            
            # Optimization logic (separate train/test to avoid leakage)
            tsp_train = apply_tsp_optimization(raw_train, dist_matrix)
            tsp_test = apply_tsp_optimization(raw_test, dist_matrix)

            # Define Scenarios
            scenarios = {
                "Actual Distance": {
                    "train": raw_train, "test": raw_test,
                    "feats": [f for f in features if f != "efficient_user"],
                    "cats": [c for c in cat_cols if c != "efficient_user"]
                },
                "TSP Optimized": {
                    "train": tsp_train, "test": tsp_test,
                    "feats": [f if f != 'Travel_Distance' else 'TSP_Distance' for f in features if f != 'efficient_user'],
                    "cats": [c for c in cat_cols if c != 'efficient_user']
                },
                "Without Distance": {
                    "train": raw_train, "test": raw_test,
                    "feats": [f for f in features if f not in ["Travel_Distance", "same_aisle", "same_lockey", "diff_level", "efficient_user"]],
                    "cats": [c for c in cat_cols if c not in ["same_aisle", "same_lockey", "diff_level", "efficient_user"]]
                }
            }

            for name, cfg in scenarios.items():
                X_train = pd.get_dummies(cfg["train"][cfg["feats"]], columns=cfg["cats"], drop_first=True)
                y_train = cfg["train"]["Time_Delta_sec"]
                X_test = pd.get_dummies(cfg["test"][cfg["feats"]], columns=cfg["cats"], drop_first=True)
                y_test = cfg["test"]["Time_Delta_sec"]
                
                X_test = X_test.reindex(columns=X_train.columns, fill_value=0)

                model = XGBRegressor(objective='reg:absoluteerror', n_estimators=1000, 
                                     learning_rate=0.05, max_depth=3, min_child_weight=5, 
                                     random_state=42, n_jobs=-1)
                model.fit(X_train, y_train)
                
                preds = model.predict(X_test)
                r2 = r2_score(y_test, preds)
                mae = mean_absolute_error(y_test, preds)


                all_results.append({
                    "Warehouse": wh,
                    "WorkCode": wc,
                    "Scenario": name,
                    "Train_End_Date": train_dates[-1],
                    "Test_Date": test_date,
                    "Train_Days_Count": len(train_dates),
                    "Train_Rows": len(X_train),
                    "Test_Rows": len(X_test),
                    "R^2": round(r2, 4),
                    "MAE": round(mae, 2)
                })

results_df = pd.DataFrame(all_results)
# Out:
# Starting Audit: Warehouse OE | Work Code 10
#   > Auditing OE-10 | Test Date: 2025-11-11...
#   > Auditing OE-10 | Test Date: 2025-11-12...
#   > Auditing OE-10 | Test Date: 2025-11-13...
#   > Auditing OE-10 | Test Date: 2025-12-01...
#   > Auditing OE-10 | Test Date: 2025-12-02...
# Starting Audit: Warehouse OE | Work Code 20
#   > Auditing OE-20 | Test Date: 2025-11-11...
#   > Auditing OE-20 | Test Date: 2025-11-12...
#   > Auditing OE-20 | Test Date: 2025-11-13...
#   > Auditing OE-20 | Test Date: 2025-12-01...
#   > Auditing OE-20 | Test Date: 2025-12-02...
# Starting Audit: Warehouse OE | Work Code 30
#   > Auditing OE-30 | Test Date: 2025-11-11...
#   > Auditing OE-30 | Test Date: 2025-11-12...
#   > Auditing OE-30 | Test Date: 2025-11-13...
#   > Auditing OE-30 | Test Date: 2025-12-01...
#   > Auditing OE-30 | Test Date: 2025-12-02...
# Starting Audit: Warehouse OF | Work Code 10
#   > Auditing OF-10 | Test Date: 2025-09-09...
#   > Auditing OF-10 | Test Date: 2025-11-10...
#   > Auditing OF-10 | Test Date: 2025-11-11...
#   > Auditing OF-10 | Test Date: 2025-11-12...
#   > Auditing OF-10 | Test Date: 2025-11-13...
#   > Auditing OF-10 | Test Date: 2025-12-01...
#   > Auditing OF-10 | Test Date: 2025-12-02...
# Starting Audit: Warehouse OF | Work Code 20
#   > Auditing OF-20 | Test Date: 2025-11-10...
#   > Auditing OF-20 | Test Date: 2025-11-11...
#   > Auditing OF-20 | Test Date: 2025-11-12...
#   > Auditing OF-20 | Test Date: 2025-11-13...
#   > Auditing OF-20 | Test Date: 2025-11-30...
#   > Auditing OF-20 | Test Date: 2025-12-01...
#   > Auditing OF-20 | Test Date: 2025-12-02...
#   > Auditing OF-20 | Test Date: 2025-12-03...
# Starting Audit: Warehouse OF | Work Code 30
#   > Auditing OF-30 | Test Date: 2025-11-10...
#   > Auditing OF-30 | Test Date: 2025-11-11...
#   > Auditing OF-30 | Test Date: 2025-11-12...
#   > Auditing OF-30 | Test Date: 2025-11-13...
#   > Auditing OF-30 | Test Date: 2025-11-30...
#   > Auditing OF-30 | Test Date: 2025-12-01...
#   > Auditing OF-30 | Test Date: 2025-12-02...
#   > Auditing OF-30 | Test Date: 2025-12-03...

# %%
results_df
# Out:
#     Warehouse WorkCode          Scenario Train_End_Date   Test_Date  \
# 0          OE       10   Actual Distance     2025-11-10  2025-11-11
# 1          OE       10     TSP Optimized     2025-11-10  2025-11-11
# 2          OE       10  Without Distance     2025-11-10  2025-11-11
# 3          OE       10   Actual Distance     2025-11-11  2025-11-12
# 4          OE       10     TSP Optimized     2025-11-11  2025-11-12
# 5          OE       10  Without Distance     2025-11-11  2025-11-12
# 6          OE       10   Actual Distance     2025-11-12  2025-11-13
# 7          OE       10     TSP Optimized     2025-11-12  2025-11-13
# 8          OE       10  Without Distance     2025-11-12  2025-11-13
# 9          OE       10   Actual Distance     2025-11-13  2025-12-01
# 10         OE       10     TSP Optimized     2025-11-13  2025-12-01
# 11         OE       10  Without Distance     2025-11-13  2025-12-01
# 12         OE       10   Actual Distance     2025-12-01  2025-12-02
# 13         OE       10     TSP Optimized     2025-12-01  2025-12-02
# 14         OE       10  Without Distance     2025-12-01  2025-12-02
# 15         OE       20   Actual Distance     2025-11-10  2025-11-11
# 16         OE       20     TSP Optimized     2025-11-10  2025-11-11
# 17         OE       20  Without Distance     2025-11-10  2025-11-11
# 18         OE       20   Actual Distance     2025-11-11  2025-11-12
# 19         OE       20     TSP Optimized     2025-11-11  2025-11-12
# 20         OE       20  Without Distance     2025-11-11  2025-11-12
# 21         OE       20   Actual Distance     2025-11-12  2025-11-13
# 22         OE       20     TSP Optimized     2025-11-12  2025-11-13
# 23         OE       20  Without Distance     2025-11-12  2025-11-13
# 24         OE       20   Actual Distance     2025-11-13  2025-12-01
# 25         OE       20     TSP Optimized     2025-11-13  2025-12-01
# 26         OE       20  Without Distance     2025-11-13  2025-12-01
# 27         OE       20   Actual Distance     2025-12-01  2025-12-02
# 28         OE       20     TSP Optimized     2025-12-01  2025-12-02
# 29         OE       20  Without Distance     2025-12-01  2025-12-02
# 30         OE       30   Actual Distance     2025-11-10  2025-11-11
# 31         OE       30     TSP Optimized     2025-11-10  2025-11-11
# 32         OE       30  Without Distance     2025-11-10  2025-11-11
# 33         OE       30   Actual Distance     2025-11-11  2025-11-12
# 34         OE       30     TSP Optimized     2025-11-11  2025-11-12
# 35         OE       30  Without Distance     2025-11-11  2025-11-12
# 36         OE       30   Actual Distance     2025-11-12  2025-11-13
# 37         OE       30     TSP Optimized     2025-11-12  2025-11-13
# 38         OE       30  Without Distance     2025-11-12  2025-11-13
# 39         OE       30   Actual Distance     2025-11-13  2025-12-01
# 40         OE       30     TSP Optimized     2025-11-13  2025-12-01
# 41         OE       30  Without Distance     2025-11-13  2025-12-01
# 38                  5       39404       8265  0.0796  24.99
# 39                  6       47669      10765  0.3125  21.20
# 40                  6       47669      10765  0.1060  24.35
# 41                  6       47669      10765  0.0648  25.15
# 42                  7       58434       6864  0.3734  20.56
# 43                  7       58434       6864  0.1207  24.42
# 44                  7       58434       6864  0.0669  25.28
# 45                  3         867        458  0.4919  24.91
# 46                  3         867        458  0.3100  32.29
# 47                  3         867        458 -0.1496  48.88
# 48                  4        1325        720  0.4967  27.16
# 49                  4        1325        720  0.3061  34.68
# 50                  4        1325        720  0.0385  43.96
# 51                  5        2045        584  0.5686  21.23
# 52                  5        2045        584  0.4122  27.30
# 53                  5        2045        584  0.0512  40.74
# 54                  6        2629        483  0.5279  24.85
# 55                  6        2629        483  0.4502  28.60
# 56                  6        2629        483  0.0510  44.47
# 57                  7        3112        641  0.5376  23.01
# 58                  7        3112        641  0.3443  29.42
# 59                  7        3112        641  0.0515  41.26
# 60                  8        3753        457  0.4478  30.39
# 61                  8        3753        457  0.2404  37.33
# 62                  8        3753        457 -0.0508  47.44
# 63                  9        4210        466  0.5649  24.38
# 64                  9        4210        466  0.3197  32.15
# 65                  9        4210        466 -0.0211  46.13
# 66                  3       10196       5029  0.6676  14.49
# 67                  3       10196       5029  0.4287  20.11
# 68                  3       10196       5029  0.0382  32.34
# 69                  4       15225       4312  0.6310  15.98
# 70                  4       15225       4312  0.4117  21.65
# 71                  4       15225       4312  0.0102  33.47
# 72                  5       19537       4359  0.6601  15.73
# 73                  5       19537       4359  0.4063  21.81
# 74                  5       19537       4359 -0.0359  35.40
# 75                  6       23896       4765  0.6480  14.76
# 76                  6       23896       4765  0.4167  20.68
# 77                  6       23896       4765  0.0031  31.46
# 78                  7       28661        809  0.5643  15.09
# 79                  7       28661        809  0.4625  18.12
# 80                  7       28661        809 -0.0386  28.59
# 81                  8       29470       5728  0.6225  15.00
# 82                  8       29470       5728  0.4119  19.57
# 83                  8       29470       5728 -0.0269  29.92
# 84                  9       35198       4329  0.6230  14.54
# 85                  9       35198       4329  0.4080  19.14
# 86                  9       35198       4329 -0.0018  29.68
# 87                 10       39527        611  0.6046  16.62
# 88                 10       39527        611  0.4965  19.55
# 89                 10       39527        611 -0.0447  39.30
# 90                  3       19204       9871  0.2747  27.80
# 91                  3       19204       9871  0.0526  32.21
# 92                  3       19204       9871 -0.0266  33.84
# 93                  4       29075       8328  0.3567  26.47
# 94                  4       29075       8328  0.1338  31.12
# 95                  4       29075       8328  0.0648  32.77
# 96                  5       37403       8609  0.3189  28.51
# 97                  5       37403       8609  0.0790  33.56
# 98                  5       37403       8609  0.0060  35.30
# 99                  6       46012       8382  0.3176  27.66
# 100                 6       46012       8382  0.0840  32.20
# 101                 6       46012       8382  0.0248  33.67
# 102                 7       54394       2724  0.3315  27.12
# 103                 7       54394       2724  0.1349  31.72
# 104                 7       54394       2724  0.0317  34.04
# 105                 8       57118       9943  0.2779  27.99
# 106                 8       57118       9943  0.0706  32.11
# 107                 8       57118       9943  0.0167  33.39
# 108                 9       67061       8093  0.3501  26.47
# 109                 9       67061       8093  0.1571  30.87
# 110                 9       67061       8093  0.0771  32.61
# 111                10       75154        304  0.4155  28.74
# 112                10       75154        304  0.2437  34.15
# 113                10       75154        304  0.0795  38.14

# %%
results_df.to_csv("time_split_results.csv", index=False)

# %% [markdown]
# # OE WorkCode 10

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter for the specific warehouse/workcode
plot_df = results_df[(results_df["Warehouse"] == 'OE') & 
                     (results_df["WorkCode"] == '10')].sort_values('Train_Days_Count')

# Changed to (1, 2) for side-by-side layout and adjusted figsize (width=18, height=7)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

# Define a consistent color scheme
palette_map = {
    "TSP Optimized": "tab:green",  
    "Actual Distance": "tab:blue", 
    "Without Distance": "tab:red"  
}

# --- Subplot 1: MAE ---
sns.lineplot(data=plot_df, x='Train_Days_Count', y='MAE', hue='Scenario', 
             marker='o', ax=ax1, palette=palette_map, errorbar=None)
ax1.set_title('MAE with different uses of distance', fontsize=14)
ax1.set_ylabel('Avg Error (MAE Seconds)', fontsize=12)
ax1.set_xlabel('Historical Training Days', fontsize=12)
ax1.grid(True, alpha=0.3)

# --- Subplot 2: R^2 Score ---
sns.lineplot(data=plot_df, x='Train_Days_Count', y='R^2', hue='Scenario', 
             marker='s', ax=ax2, palette=palette_map, errorbar=None)
ax2.axhline(0, color='black', linestyle='--', alpha=0.6, label='Mean Baseline')
ax2.set_title('R² Score with different uses of distance', fontsize=14)
ax2.set_ylabel('R² Score', fontsize=12)
ax2.set_xlabel('Historical Training Days', fontsize=12)
ax2.grid(True, alpha=0.3)

# Add clear legends for both
ax1.legend(title='Scenario')
ax2.legend(title='Scenario')

plt.tight_layout()
plt.show()

# %% [markdown]
# # OE WorkCode 20

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter for the specific warehouse/workcode
plot_df = results_df[(results_df["Warehouse"] == 'OE') & 
                     (results_df["WorkCode"] == '20')].sort_values('Train_Days_Count')

# Changed to (1, 2) for side-by-side layout and adjusted figsize (width=18, height=7)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

# Define a consistent color scheme
palette_map = {
    "TSP Optimized": "tab:green",  
    "Actual Distance": "tab:blue", 
    "Without Distance": "tab:red"  
}

# --- Subplot 1: MAE ---
sns.lineplot(data=plot_df, x='Train_Days_Count', y='MAE', hue='Scenario', 
             marker='o', ax=ax1, palette=palette_map, errorbar=None)
ax1.set_title('MAE with different uses of distance', fontsize=14)
ax1.set_ylabel('Avg Error (MAE Seconds)', fontsize=12)
ax1.set_xlabel('Historical Training Days', fontsize=12)
ax1.grid(True, alpha=0.3)

# --- Subplot 2: R^2 Score ---
sns.lineplot(data=plot_df, x='Train_Days_Count', y='R^2', hue='Scenario', 
             marker='s', ax=ax2, palette=palette_map, errorbar=None)
ax2.axhline(0, color='black', linestyle='--', alpha=0.6, label='Mean Baseline')
ax2.set_title('R² Score with different uses of distance', fontsize=14)
ax2.set_ylabel('R² Score', fontsize=12)
ax2.set_xlabel('Historical Training Days', fontsize=12)
ax2.grid(True, alpha=0.3)

# Add clear legends for both
ax1.legend(title='Scenario')
ax2.legend(title='Scenario')

plt.tight_layout()
plt.show()

# %% [markdown]
# # OE WorkCode 30

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter for the specific warehouse/workcode
plot_df = results_df[(results_df["Warehouse"] == 'OE') & 
                     (results_df["WorkCode"] == '30')].sort_values('Train_Days_Count')

# Changed to (1, 2) for side-by-side layout and adjusted figsize (width=18, height=7)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

# Define a consistent color scheme
palette_map = {
    "TSP Optimized": "tab:green",  
    "Actual Distance": "tab:blue", 
    "Without Distance": "tab:red"  
}

# --- Subplot 1: MAE ---
sns.lineplot(data=plot_df, x='Train_Days_Count', y='MAE', hue='Scenario', 
             marker='o', ax=ax1, palette=palette_map, errorbar=None)
ax1.set_title('MAE with different uses of distance', fontsize=14)
ax1.set_ylabel('Avg Error (MAE Seconds)', fontsize=12)
ax1.set_xlabel('Historical Training Days', fontsize=12)
ax1.grid(True, alpha=0.3)

# --- Subplot 2: R^2 Score ---
sns.lineplot(data=plot_df, x='Train_Days_Count', y='R^2', hue='Scenario', 
             marker='s', ax=ax2, palette=palette_map, errorbar=None)
ax2.axhline(0, color='black', linestyle='--', alpha=0.6, label='Mean Baseline')
ax2.set_title('R² Score with different uses of distance', fontsize=14)
ax2.set_ylabel('R² Score', fontsize=12)
ax2.set_xlabel('Historical Training Days', fontsize=12)
ax2.grid(True, alpha=0.3)

# Add clear legends for both
ax1.legend(title='Scenario')
ax2.legend(title='Scenario')

plt.tight_layout()
plt.show()

# %% [markdown]
# # OF WorkCode 10

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter for the specific warehouse/workcode
plot_df = results_df[(results_df["Warehouse"] == 'OF') & 
                     (results_df["WorkCode"] == '10')].sort_values('Train_Days_Count')

# Changed to (1, 2) for side-by-side layout and adjusted figsize (width=18, height=7)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

# Define a consistent color scheme
palette_map = {
    "TSP Optimized": "tab:green",  
    "Actual Distance": "tab:blue", 
    "Without Distance": "tab:red"  
}

# --- Subplot 1: MAE ---
sns.lineplot(data=plot_df, x='Train_Days_Count', y='MAE', hue='Scenario', 
             marker='o', ax=ax1, palette=palette_map, errorbar=None)
ax1.set_title('MAE with different uses of distance', fontsize=14)
ax1.set_ylabel('Avg Error (MAE Seconds)', fontsize=12)
ax1.set_xlabel('Historical Training Days', fontsize=12)
ax1.grid(True, alpha=0.3)

# --- Subplot 2: R^2 Score ---
sns.lineplot(data=plot_df, x='Train_Days_Count', y='R^2', hue='Scenario', 
             marker='s', ax=ax2, palette=palette_map, errorbar=None)
ax2.axhline(0, color='black', linestyle='--', alpha=0.6, label='Mean Baseline')
ax2.set_title('R² Score with different uses of distance', fontsize=14)
ax2.set_ylabel('R² Score', fontsize=12)
ax2.set_xlabel('Historical Training Days', fontsize=12)
ax2.grid(True, alpha=0.3)

# Add clear legends for both
ax1.legend(title='Scenario')
ax2.legend(title='Scenario')

plt.tight_layout()
plt.show()

# %% [markdown]
# # OF WorkCode 20

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter for the specific warehouse/workcode
plot_df = results_df[(results_df["Warehouse"] == 'OF') & 
                     (results_df["WorkCode"] == '20')].sort_values('Train_Days_Count')

# Changed to (1, 2) for side-by-side layout and adjusted figsize (width=18, height=7)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

# Define a consistent color scheme
palette_map = {
    "TSP Optimized": "tab:green",  
    "Actual Distance": "tab:blue", 
    "Without Distance": "tab:red"  
}

# --- Subplot 1: MAE ---
sns.lineplot(data=plot_df, x='Train_Days_Count', y='MAE', hue='Scenario', 
             marker='o', ax=ax1, palette=palette_map, errorbar=None)
ax1.set_title('MAE with different uses of distance', fontsize=14)
ax1.set_ylabel('Avg Error (MAE Seconds)', fontsize=12)
ax1.set_xlabel('Historical Training Days', fontsize=12)
ax1.grid(True, alpha=0.3)

# --- Subplot 2: R^2 Score ---
sns.lineplot(data=plot_df, x='Train_Days_Count', y='R^2', hue='Scenario', 
             marker='s', ax=ax2, palette=palette_map, errorbar=None)
ax2.axhline(0, color='black', linestyle='--', alpha=0.6, label='Mean Baseline')
ax2.set_title('R² Score with different uses of distance', fontsize=14)
ax2.set_ylabel('R² Score', fontsize=12)
ax2.set_xlabel('Historical Training Days', fontsize=12)
ax2.grid(True, alpha=0.3)

# Add clear legends for both
ax1.legend(title='Scenario')
ax2.legend(title='Scenario')

plt.tight_layout()
plt.show()

# %% [markdown]
# # OF WorkCode 30

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter for the specific warehouse/workcode
plot_df = results_df[(results_df["Warehouse"] == 'OF') & 
                     (results_df["WorkCode"] == '30')].sort_values('Train_Days_Count')

# Changed to (1, 2) for side-by-side layout and adjusted figsize (width=18, height=7)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

# Define a consistent color scheme
palette_map = {
    "TSP Optimized": "tab:green",  
    "Actual Distance": "tab:blue", 
    "Without Distance": "tab:red"  
}

# --- Subplot 1: MAE ---
sns.lineplot(data=plot_df, x='Train_Days_Count', y='MAE', hue='Scenario', 
             marker='o', ax=ax1, palette=palette_map, errorbar=None)
ax1.set_title('MAE with different uses of distance', fontsize=14)
ax1.set_ylabel('Avg Error (MAE Seconds)', fontsize=12)
ax1.set_xlabel('Historical Training Days', fontsize=12)
ax1.grid(True, alpha=0.3)

# --- Subplot 2: R^2 Score ---
sns.lineplot(data=plot_df, x='Train_Days_Count', y='R^2', hue='Scenario', 
             marker='s', ax=ax2, palette=palette_map, errorbar=None)
ax2.axhline(0, color='black', linestyle='--', alpha=0.6, label='Mean Baseline')
ax2.set_title('R² Score with different uses of distance', fontsize=14)
ax2.set_ylabel('R² Score', fontsize=12)
ax2.set_xlabel('Historical Training Days', fontsize=12)
ax2.grid(True, alpha=0.3)

# Add clear legends for both
ax1.legend(title='Scenario')
ax2.legend(title='Scenario')

plt.tight_layout()
plt.show()
