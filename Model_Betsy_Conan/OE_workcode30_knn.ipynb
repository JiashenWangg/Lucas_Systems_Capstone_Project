# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score


# Insert warehouse name here
warehouse_name = "OE"
# Insert user id here
user = "betsyfrdmn"
# GitHub repo
base = "Lucas_Systems_Capstone_Project"

# Load your processed data
df = pd.read_parquet(f"/Users/{user}/{base}/data/processed/oe_detailed.parquet")

# Filter for only Work Code 30
df = df[df["WorkCode"] == "30"]

# Drop missing rows for important variables
df = df.dropna(subset=['Weight', 'Cube', 'Level', 'Time_Delta_sec', 'Travel_Distance'])

# %%
X = df[['Weight', 'Cube', 'Level', 'Travel_Distance']]
y = df['Time_Delta_sec']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)


scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 5 neighbors, uniform weighting, with Travel Distance
knn = KNeighborsRegressor(n_neighbors=5, weights='uniform')
knn.fit(X_train_scaled, y_train)

predictions = knn.predict(X_test_scaled)

mae_5_dist = mean_absolute_error(y_test, predictions)

print(f"Mean Absolute Error: {mae_5_dist}")
# Out:
# Mean Absolute Error: 32.98706440371125

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'knn' is your trained model and X_test_scaled/y_test are ready
y_pred = knn.predict(X_test_scaled)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.5, color='teal')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--r', linewidth=2) # Diagonal line

plt.title('Slide 2: Actual vs. Predicted Warehouse Time')
plt.xlabel('Actual Time')
plt.ylabel('Predicted Time (kNN)')
plt.grid(True)
plt.show()

# %%
X = df[['Weight', 'Cube', 'Level']]
y = df['Time_Delta_sec']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)


scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 5 neighbors, uniform weighting, with Travel Distance
knn = KNeighborsRegressor(n_neighbors=5, weights='uniform')
knn.fit(X_train_scaled, y_train)

predictions = knn.predict(X_test_scaled)

mae_5_nodist = mean_absolute_error(y_test, predictions)

print(f"Mean Absolute Error: {mae_5_nodist}")
# Out:
# Mean Absolute Error: 38.714176601040954

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'knn' is your trained model and X_test_scaled/y_test are ready
y_pred = knn.predict(X_test_scaled)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.5, color='teal')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--r', linewidth=2) # Diagonal line

plt.title('Slide 2: Actual vs. Predicted Warehouse Time')
plt.xlabel('Actual Time')
plt.ylabel('Predicted Time (kNN)')
plt.grid(True)
plt.show()

# %%
X = df[['Weight', 'Cube', 'Level', 'Travel_Distance']]
y = df['Time_Delta_sec']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)


scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 5 neighbors, distance weighting, with Travel Distance
knn = KNeighborsRegressor(n_neighbors=5, weights='distance')
knn.fit(X_train_scaled, y_train)

predictions = knn.predict(X_test_scaled)

mae = mean_absolute_error(y_test, predictions)

print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Absolute Error: 33.10863431272129

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'knn' is your trained model and X_test_scaled/y_test are ready
y_pred = knn.predict(X_test_scaled)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.5, color='teal')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--r', linewidth=2) # Diagonal line

plt.title('Slide 2: Actual vs. Predicted Warehouse Time')
plt.xlabel('Actual Time')
plt.ylabel('Predicted Time (kNN)')
plt.grid(True)
plt.show()

# %%
X = df[['Weight', 'Cube', 'Level', 'Travel_Distance']]
y = df['Time_Delta_sec']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)


scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 10 neighbors, uniform weighting, with Travel Distance
knn = KNeighborsRegressor(n_neighbors=10, weights='uniform')
knn.fit(X_train_scaled, y_train)

predictions = knn.predict(X_test_scaled)

mae_10_dist = mean_absolute_error(y_test, predictions)

print(f"Mean Absolute Error: {mae_10_dist}")
# Out:
# Mean Absolute Error: 31.971696213321266

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'knn' is your trained model and X_test_scaled/y_test are ready
y_pred = knn.predict(X_test_scaled)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.5, color='teal')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--r', linewidth=2) # Diagonal line

plt.title('Actual vs. Predicted Warehouse Time')
plt.xlabel('Actual Time')
plt.ylabel('Predicted Time (kNN)')
plt.grid(True)
plt.show()

# %%
X = df[['Weight', 'Cube', 'Level', 'Travel_Distance']]
y = df['Time_Delta_sec']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)


scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 10 neighbors, distance weighting, with Travel Distance
knn = KNeighborsRegressor(n_neighbors=10, weights='distance')
knn.fit(X_train_scaled, y_train)

predictions = knn.predict(X_test_scaled)

mae = mean_absolute_error(y_test, predictions)

print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Absolute Error: 32.093403614375475

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'knn' is your trained model and X_test_scaled/y_test are ready
y_pred = knn.predict(X_test_scaled)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.5, color='teal')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--r', linewidth=2) # Diagonal line

plt.title('Slide 2: Actual vs. Predicted Warehouse Time')
plt.xlabel('Actual Time')
plt.ylabel('Predicted Time (kNN)')
plt.grid(True)
plt.show()

# %%
X = df[['Weight', 'Cube', 'Level']]
y = df['Time_Delta_sec']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)


scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 10 neighbors, uniform weighting, no Travel Distance
knn = KNeighborsRegressor(n_neighbors=10, weights='uniform')
knn.fit(X_train_scaled, y_train)

predictions = knn.predict(X_test_scaled)

mae_10_nodist = mean_absolute_error(y_test, predictions)

print(f"Mean Absolute Error: {mae_10_nodist}")
# Out:
# Mean Absolute Error: 36.66460989665837

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'knn' is your trained model and X_test_scaled/y_test are ready
y_pred = knn.predict(X_test_scaled)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.5, color='teal')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--r', linewidth=2) # Diagonal line

plt.title('Slide 2: Actual vs. Predicted Warehouse Time')
plt.xlabel('Actual Time')
plt.ylabel('Predicted Time (kNN)')
plt.grid(True)
plt.show()

# %%
X = df[['Weight', 'Cube', 'Level']]
y = df['Time_Delta_sec']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)


scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 10 neighbors, distance weighting, no Travel Distance
knn = KNeighborsRegressor(n_neighbors=10, weights='distance')
knn.fit(X_train_scaled, y_train)

predictions = knn.predict(X_test_scaled)

mae = mean_absolute_error(y_test, predictions)

print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Absolute Error: 37.1133295828863

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'knn' is your trained model and X_test_scaled/y_test are ready
y_pred = knn.predict(X_test_scaled)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.5, color='teal')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--r', linewidth=2) # Diagonal line

plt.title('Slide 2: Actual vs. Predicted Warehouse Time')
plt.xlabel('Actual Time')
plt.ylabel('Predicted Time (kNN)')
plt.grid(True)
plt.show()

# %%
# Use the mae_scores and k_range from your previous run
plt.figure(figsize=(10, 5))
plt.plot(k_range, mae_scores, marker='o', linestyle='-', color='#2c3e50', markerfacecolor='#e74c3c')

# Annotate the 'Hero' point
plt.annotate('Optimal k=10\n(Best Balance)', xy=(10, mae_scores[9]), xytext=(15, mae_scores[5]+2),
             arrowprops=dict(facecolor='black', shrink=0.08))

plt.title('Optimizing k for Minimum Error and Generalizability')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Mean Absolute Error (MAE)')
plt.axvline(x=10, color='red', linestyle='--')
plt.grid(alpha=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[131], line 3
#       1 # Use the mae_scores and k_range from your previous run
#       2 plt.figure(figsize=(10, 5))
# ----> 3 plt.plot(k_range, mae_scores, marker='o', linestyle='-', color='#2c3e50', markerfacecolor='#e74c3c')
#       5 # Annotate the 'Hero' point
#       6 plt.annotate('Optimal k=10\n(Best Balance)', xy=(10, mae_scores[9]), xytext=(15, mae_scores[5]+2),
#       7              arrowprops=dict(facecolor='black', shrink=0.08))
#
# NameError: name 'k_range' is not defined

# %%
data = [[5, 'Yes', round(mae_5_dist, 2)],
        [5, 'No', round(mae_5_nodist, 2)],
#        [5, 'Distance', 'Yes', '59.13635403913226'],
        [10, 'Yes', round(mae_10_dist, 2)],
#        [10, 'Distance', 'Yes', '57.88467008439773'],
        [10, 'No', round(mae_10_nodist, 2)]]
#        [10, 'Distance', 'Yes', '49.87654321098765'],
#        [10, 'Distance', 'No', '64.4370365792091']]
summary = pd.DataFrame(data, columns=['k', 'Distance Included', 'MAE'])
summary
# Out:
#     k Distance Included    MAE
# 0   5               Yes  32.99
# 1   5                No  38.71
# 2  10               Yes  31.97
# 3  10                No  36.66

# %%
summary2 = pd.DataFrame(columns=['', 'Distance Included', 'Distance Not Included'],
                        data=[['k = 5', round(mae_5_dist, 2), round(mae_5_nodist, 2)],
                              ['k = 10', round(mae_10_dist, 2), round(mae_10_nodist, 2)]])
summary2
# Out:
#            Distance Included  Distance Not Included
# 0   k = 5              32.99                  38.71
# 1  k = 10              31.97                  36.66
