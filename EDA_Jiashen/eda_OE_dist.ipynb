# %%
import pandas as pd
import numpy as np

path = "../data/distance_matrices/distance_matrix_OE.csv"
Distance = pd.read_csv(path, index_col=0)

for c in Distance.columns:
    Distance[c] = pd.to_numeric(Distance[c], errors="coerce")

display(Distance.head())
# Out:
#           08|03|||  08|05|||  08|07|||  08|09|||  10|04|||  10|06|||  \
# 08|03|||         0       414       389       364       304       287
# 08|05|||        25         0       414       389       329       312
# 08|07|||        50        25         0       414       354       337
# 08|09|||        75        50        25         0       379       362
# 10|04|||       484       459       434       410         0        19
#
#           10|08|||  10|10|||  10|12|||  10|14|||  ...  |Start L3  |Start L4  \
# 08|03|||       271       255       240       223  ...       1094       1068
# 08|05|||       296       280       265       248  ...       1119       1093
# 08|07|||       321       305       290       273  ...       1144       1118
# 08|09|||       346       330       315       298  ...       1169       1143
# 10|04|||        35        51        67        81  ...       1120       1074
#
#           |Start L5  |Start L6  |Start R2  |Start R3  |Start R4  |Start R5  \
# ...

# %%
# Find distance between Aisle 08 Bay 03(Column '08|03|||') and Aisle 08 Bay 05(Row '08|05|||')
print(Distance.loc["08|05|||", "08|03|||"])
print(Distance.loc["08|03|||", "08|05|||"])

print(Distance.loc["12|10|||", "14|28|||"])
print(Distance.loc["14|28|||", "12|10|||"])
# Out:
# 25
# 414
# 220
# 652
